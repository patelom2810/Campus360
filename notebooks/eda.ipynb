# %% [markdown]
# # Exploratory Data Analysis: Student Analytics Platform
# Analysis of raw and stitched student datasets across academics, lifestyle, and career readiness.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load stitched warehouse table
df_wide = pd.read_csv('../data/processed/student_master_wide.csv')
print("Shape:", df_wide.shape)
df_wide.head()
